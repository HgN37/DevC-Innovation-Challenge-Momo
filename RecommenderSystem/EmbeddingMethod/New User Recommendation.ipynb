# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import json

# %%
merchants = pd.read_csv("./data/modified_merchants.csv")
merchants.head(5)
# Out:
#    Unnamed: 0           service_id             store_id service_group  \
# 0           0  1058241667815469540   249887925492461203         other
# 1           1  1058241667815469540  6272474026035536581         other
# 2           2  8073873840719601655  2217087971996193230      beverage
# 3           3  1058241667815469540  7296552596579579660         other
# 4           4  1058241667815469540  4707467693322385152         other
#
#                            merchant_name  \
# 0   CÔNG TY CP TMDV TVTK THỜI TRANG VIỆT
# 1   CÔNG TY CP TMDV TVTK THỜI TRANG VIỆT
# 2  HỘ KINH DOANH - QUÁCH THỊ HƯƠNG DUYÊN
# 3   CÔNG TY CP TMDV TVTK THỜI TRANG VIỆT
# 4   CÔNG TY CP TMDV TVTK THỜI TRANG VIỆT
#
#                                     merchant_address  \
# 0              189A Hai Bà Trưng , P.6, Quận 3 TPHCM
# 1              189A Hai Bà Trưng , P.6, Quận 3 TPHCM
# 2  444 Hoàng Văn Thụ, Phường 2, Quận Tân Bình, Th...
# 3              189A Hai Bà Trưng , P.6, Quận 3 TPHCM
# 4              189A Hai Bà Trưng , P.6, Quận 3 TPHCM
#
#                       store_name  \
# 0    Concept Nguyễn Trãi Cần Thơ
# 1              Concept Hậu Giang
# 2         Sharetea Hoàng Văn Thụ
# 3  Concept Cách Mạng tháng 8 HCM
# 4         Concept Vạnh Hạnh Mall
#
#                                        store_address store_longitude  \
# 0       41-41A-43 Nguyễn Trãi, Q. Ninh Kiều, Cần Thơ      105.785046
# 1       Số 410 Hậu Giang, Phường 12, Quận 6, Tp. HCM      106.638935
# 2  444 Hoàng Văn Thụ, Phường 4, Quận Tân Bình, Th...      106.655742
# 3  Số 484 - 486 Cách Mạng Tháng Tám, Phường 11, Q...      106.668518
# 4  TTTM,Số 11 Sư Vạn Hạnh, Đường 3/2, Phường 12, ...      106.669971
#
#   store_latitude                                unique_id     modified_service
# 0      10.040508   1058241667815469540-249887925492461203  1058241667815469540
# 1      10.749251  1058241667815469540-6272474026035536581  1058241667815469540
# 2      10.795501  8073873840719601655-2217087971996193230  8073873840719601655
# 3      10.784919  1058241667815469540-7296552596579579660  1058241667815469540
# 4      10.769976  1058241667815469540-4707467693322385152  1058241667815469540

# %%
transactions = pd.read_csv('./data/transactions2train.csv')
transactions.sample(5)
# Out:
#         Unnamed: 0              user_id           service_id   amount  \
# 508706      508706  8517959191213251098  4627806457648007688   721000
# 492509      492509  8270736521891156114  4522620599497170471   591000
# 556201      556201   923804423719917884  6617482751287210054  1020000
# 139233      139233   304925720646753104  9091730908646524368   229000
# 245174      245174  4608171871096713525  1413807917068409262   222000
#
#         visit_count  total_amount     favor  avr_amount  rating service_group  \
# 508706            1       4892000  0.147383    196000.0       1           fnb
# 492509            1       3724000  0.158700    787000.0       0          food
# 556201            2       2896000  0.352210    199500.0       1   supermarket
# 139233            1        973000  0.235355    142000.0       1      beverage
# 245174            1       5099000  0.043538    181000.0       1      beverage
#
#         user_code  service_code
# 508706     101531           245
# 492509      98298           224
# 556201     111049           382
# 139233      27759           535
# 245174      48914            38

# %%
total_amount = transactions.groupby('service_id', as_index = False)['amount'].mean()
total_visit = transactions.groupby('service_id', as_index = False)['visit_count'].sum()

# %%
result = pd.concat([total_amount, total_visit], axis=1, sort=False)
result = result.loc[:,~result.columns.duplicated()]

# %%
result['amount'] = result['amount'] / 1000

# %%
result.head()
# Out:
#             service_id      amount  visit_count
# 0   100459171840484639  394.821380         1088
# 1   100670421557790535  455.711584          554
# 2  1011115523130927864  315.156684         3427
# 3  1020517967048203191  428.581081         1095
# 4  1023280480942069518  413.481405          667

# %%
result.describe()
# Out:
#             amount   visit_count
# count   549.000000    549.000000
# mean    395.837612   1449.825137
# std     125.085164   1636.403466
# min       1.000000      1.000000
# 25%     399.689861    802.000000
# 50%     424.482543   1242.000000
# 75%     443.167647   1725.000000
# max    1382.500000  19408.000000

# %% [markdown]
# ### Weight Rating Formular
# ![Screen%20Shot%202019-10-01%20at%2018.56.11.png](attachment:Screen%20Shot%202019-10-01%20at%2018.56.11.png)

# %% [markdown]
# ### Custom Weight Rating Formula:
# - v: number of total visit of service
# - m: minimum visit (500)
# - R: mean (total amount) of service
# - C: mean of total visit of all service

# %%
total_visits = result['visit_count'].sum()
total_services = result['visit_count'].nunique()
C = total_visits / total_services
C
# Out:
# 1846.7610208816704

# %%
def calculate_weight_rating (v, R):
    m = 500
    C = total_visits / total_services
    score = ((v / (v + m))*R ) + ((m / (v + m)) * C)
    return score

# %%
result['score'] = result.apply(lambda x: calculate_weight_rating(x['visit_count'], x['amount']), axis=1)

# %%
result.sort_values(by = 'score').head(5)
# Out:
#               service_id      amount  visit_count       score
# 435  7341550893129842017  190.355147        18855  233.145275
# 318  5654538597012118714  229.768862         7264  333.902824
# 397  6867086828130189483  268.835966         5396  402.649149
# 177  3771801775643244829  262.253061         5136  402.823320
# 169  3615982237552954784  289.336152         6319  403.533605

# %%
result_list = result[['service_id','score']].sort_values(by = 'score')
result_list.to_json(orient='records')
# Out:
# '[{"service_id":"7341550893129842017","score":233.1452750599},{"service_id":"5654538597012118714","score":333.902824061},{"service_id":"6867086828130189483","score":402.649149353},{"service_id":"3771801775643244829","score":402.823320243},{"service_id":"3615982237552954784","score":403.533605113},{"service_id":"6833267496949447871","score":415.9339133161},{"service_id":"2180187955578894951","score":441.4199143078},{"service_id":"9105773273715501159","score":443.5654174006},{"service_id":"3398611740160718989","score":447.890913063},{"service_id":"8421950360944077064","score":450.1562346791},{"service_id":"1155562636157432983","score":458.5109056222},{"service_id":"7870989550813941047","score":460.6914442204},{"service_id":"754456615597202420","score":477.5675335334},{"service_id":"1929318416976556438","score":490.8116849409},{"service_id":"7261616585863472745","score":504.0935766312},{"service_id":"1011115523130927864","score":510.1661488678},{"service_id":"7310160001796817277","score":515.2844266295},{"service_id":"5903031011860056729","score":526.4174762158},{"service_id":"5494030965430035042","score":545.7962061063},{"service_id":"1413807917068409262","score":552.5386926771},{"service_id":"4474770828003663379","score":552.5636952035},{"service_id":"3797980347767515401","score":553.9457984207},{"service_id":"5350129378332776599","score":571.9025042574},{"service_id":"4736617612607365545","score":572.7230620137},{"service_id":"6808347026108568574","score":574.9966061531},{"service_id":"946180032524845328","score":576.7446500002},{"service_id":"8714321951742318973","score":579.2183468458},{"service_id":"1790288908874625201","score":581.8849614402},{"service_id":"9091730908646524368","score":586.2238424753},{"service_id":"7800199981419598821","score":589.7139064096},{"service_id":"3315835320223835013","score":591.9077510887},{"service_id":"8556496424374803715","score":597.8719527078},{"service_id":"2462637464558474200","score":603.8131943296},{"service_id":"7956496375996231149","score":604.8582105119},{"service_id":"805375962505978627","score":605.5479142524},{"service_id":"7602277713859172296","score":612.6389138973},{"service_id":"7165089198541247961","score":613.0551889606},{"service_id":"1691048167182528780","score":619.9739157642},{"service_id":"6481221346259782889","score":624.1030693159},{"service_id":"7006999597222169608","score":629.0910955908},{"service_id":"580914346439077050","score":636.8220603853},{"service_id":"1238760765024775632","score":638.791015554},{"service_id":"5272997585295521260","score":639.6866477895},{"service_id":"2097810288464482195","score":640.0049171181},{"service_id":"9045274477408763399","score":642.681155893},{"service_id":"2976045368419517725","score":651.540438233},{"service_id":"6590908705817898024","score":653.1103979513},{"service_id":"2651480655471329551","score":654.7318155345},{"service_id":"7388968636509119332","score":657.928841209},{"service_id":"6573947514783036540","score":658.598750644},{"service_id":"6617482751287210054","score":659.6249480486},{"service_id":"2094705476432891136","score":659.93037757},{"service_id":"7162169384463203448","score":661.5423372676},{"service_id":"5610008375107306861","score":666.5629581645},{"service_id":"8073873840719601655","score":674.860313905},{"service_id":"1643362567822364399","score":676.6144781454},{"service_id":"5314294513087666829","score":678.2690164638},{"service_id":"6716191339412858465","score":679.5770030943},{"service_id":"4501300687807117702","score":679.6926120668},{"service_id":"8203460032407458181","score":681.1439221107},{"service_id":"822043397492434507","score":682.2960987535},{"service_id":"5574105295340017131","score":683.5954880834},{"service_id":"7683040491188562102","score":690.1288934131},{"service_id":"6813810437735499528","score":692.8142844162},{"service_id":"8405759108835333857","score":694.9659708831},{"service_id":"3232333568492323330","score":696.9405817259},{"service_id":"6072375905080339929","score":697.18424257 ...
